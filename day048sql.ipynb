# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/100-days-sql/blob/main/day048sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('/content/company.db')

# Helper function to run SQL queries
def run_sql(query):
    return pd.read_sql_query(query, conn)

print("✅ Connected to company.db successfully!")
# Out:
# ✅ Connected to company.db successfully!

# %%
# Topic: Introduction

# %%
#1
run_sql("""SELECT
          employees.first_name,
          employees.last_name,
          departments.department_name
          FROM employees
          JOIN departments
          ON employees.department_id = departments.department_id;""")
# Out:
#    first_name last_name   department_name
# 0       Aarav     Patel                HR
# 1      Vivaan     Patel           Finance
# 2      Aditya       Das                IT
# 3        Riya       Das         Marketing
# 4       Priya       Das             Sales
# 5        Neha    Taylor        Operations
# 6       Rahul       Roy           Support
# 7        Amit       Roy             Legal
# 8        John     Brown  Data Engineering
# 9        Emma     Kumar          Security
# 10       Noah     Singh                HR
# 11     Olivia       Roy           Finance
# 12       Liam     Singh                IT
# 13     Sophia       Roy         Marketing
# 14     Ananya     Singh             Sales
# 15      Karan    Taylor        Operations
# 16      Rohan     Singh           Support
# 17      Sneha    Sharma             Legal
# 18      David     Singh  Data Engineering
# 19       Sara    Taylor          Security
# 20      Arjun    Taylor                HR
# ...

# %%
#2 Display each order along with customer name.
run_sql("""SELECT
        orders.order_id,
        customers.first_name,
        customers.last_name
        FROM orders
        JOIN customers
        ON orders.customer_id = customers.customer_id;""")
# Out:
#     order_id first_name last_name
# 0          1      Aisha     Kumar
# 1          2      Akash     Patel
# 2          3      Nitin    Wilson
# 3          4     Deepak    Taylor
# 4          5     Anjali     Singh
# ..       ...        ...       ...
# 95        96     Simran       Das
# 96        97       Ritu    Sharma
# 97        98       Yash       Das
# 98        99     Simran       Das
# 99       100       Ritu    Sharma
#
# [100 rows x 3 columns]

# %%
#3
run_sql("""SELECT
    product_id,
    product_name,
    category,
    price
    FROM products;""")
# Out:
#     product_id        product_name    category    price
# 0            1      Laptop Model 1      Laptop  90499.0
# 1            2      Laptop Model 2      Laptop  90999.0
# 2            3      Laptop Model 3      Laptop  91499.0
# 3            4      Laptop Model 4      Laptop  91999.0
# 4            5      Mobile Model 1      Mobile  30499.0
# 5            6      Mobile Model 2      Mobile  30999.0
# 6            7      Mobile Model 3      Mobile  31499.0
# 7            8      Mobile Model 4      Mobile  31999.0
# 8            9  Headphones Model 1  Headphones   5499.0
# 9           10  Headphones Model 2  Headphones   5999.0
# 10          11  Headphones Model 3  Headphones   6499.0
# 11          12  Headphones Model 4  Headphones   6999.0
# 12          13     Monitor Model 1     Monitor  16499.0
# 13          14     Monitor Model 2     Monitor  16999.0
# 14          15     Monitor Model 3     Monitor  17499.0
# 15          16     Monitor Model 4     Monitor  17999.0
# ...

# %%
#4
run_sql("""SELECT
       orders.order_id,
       customers.first_name,
       customers.last_name,
       products.product_name
       FROM orders
       JOIN customers
       ON orders.customer_id = customers.customer_id
       JOIN products
       ON orders.product_id = products.product_id;""")
# Out:
#     order_id first_name last_name        product_name
# 0          1      Aisha     Kumar      Laptop Model 2
# 1          2      Akash     Patel     Monitor Model 4
# 2          3      Nitin    Wilson       Mouse Model 4
# 3          4     Deepak    Taylor       Mouse Model 3
# 4          5     Anjali     Singh      Laptop Model 3
# ..       ...        ...       ...                 ...
# 95        96     Simran       Das      Mobile Model 4
# 96        97       Ritu    Sharma  Headphones Model 3
# 97        98       Yash       Das      Mobile Model 4
# 98        99     Simran       Das       Mouse Model 3
# 99       100       Ritu    Sharma    Keyboard Model 1
#
# [100 rows x 4 columns]

# %%
#5
run_sql("""SELECT
        employees.first_name,
        employees.last_name,
        departments.department_name,
        departments.location
        FROM employees
        LEFT JOIN departments
        ON employees.department_id = departments.department_id;""")
# Out:
#    first_name last_name   department_name   location
# 0       Aarav     Patel                HR  Bangalore
# 1      Vivaan     Patel           Finance     Mumbai
# 2      Aditya       Das                IT  Bangalore
# 3        Riya       Das         Marketing      Delhi
# 4       Priya       Das             Sales  Hyderabad
# 5        Neha    Taylor        Operations       Pune
# 6       Rahul       Roy           Support    Chennai
# 7        Amit       Roy             Legal      Delhi
# 8        John     Brown  Data Engineering  Bangalore
# 9        Emma     Kumar          Security    Kolkata
# 10       Noah     Singh                HR  Bangalore
# 11     Olivia       Roy           Finance     Mumbai
# 12       Liam     Singh                IT  Bangalore
# 13     Sophia       Roy         Marketing      Delhi
# 14     Ananya     Singh             Sales  Hyderabad
# 15      Karan    Taylor        Operations       Pune
# 16      Rohan     Singh           Support    Chennai
# ...

# %%
# Bonus Challenge
run_sql("""SELECT
       customers.customer_id,
       customers.first_name,
       customers.last_name,
       COUNT(orders.order_id) AS total_orders
       FROM customers

       INNER JOIN orders
       ON customers.customer_id = orders.customer_id
       GROUP BY
       customers.customer_id,
       customers.first_name,
       customers.last_name;""")
# Out:
#     customer_id first_name last_name  total_orders
# 0             1      Akash    Sharma             1
# 1             2       Ritu       Das             3
# 2             3      Mohit     Kumar             3
# 3             4     Simran       Das             3
# 4             5       Yash    Sharma             3
# 5             7     Deepak    Wilson             1
# 6             8      Komal       Roy             3
# 7             9      Nitin     Brown             4
# 8            10      Aisha     Kumar             2
# 9            11      Akash     Patel             3
# 10           12       Ritu     Kumar             1
# 11           13      Mohit       Das             6
# 12           14     Simran    Taylor             5
# 13           15       Yash    Sharma             5
# 14           16     Anjali     Singh             5
# 15           17     Deepak    Taylor             2
# 16           18      Komal     Singh             1
# ...
