# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('/content/company.db')

# Helper function to run SQL queries
def run_sql(query):
    return pd.read_sql_query(query, conn)

print("✅ Connected to company.db successfully!")
# Out:
# ✅ Connected to company.db successfully!

# %%
# Topic: Advaced practice using WHERE, AND, OR, NOT, IN, and BETWEEN.

# %%
#1 Display customers whose city is  NOT 'anga
run_sql("""SELECT * FROM employees
WHERE employee_id BETWEEN 4 AND 8;""")
# Out:
#    employee_id first_name last_name  department_id   hire_date    salary  \
# 0            4       Riya       Das              4  2024-02-16  117500.0
# 1            5      Priya       Das              5  2020-01-29  120000.0
# 2            6       Neha    Taylor              6  2024-11-24   67500.0
# 3            7      Rahul       Roy              7  2019-02-23   90000.0
# 4            8       Amit       Roy              8  2021-05-07  105000.0
#
#              job_title       city                     email
# 0  Marketing Executive      Delhi     riya.das4@company.com
# 1      Sales Executive     Mumbai    priya.das5@company.com
# 2   Operations Analyst  Hyderabad  neha.taylor6@company.com
# 3     Support Engineer     Mumbai    rahul.roy7@company.com
# 4        Legal Advisor  Bangalore     amit.roy8@company.com

# %%
#2 Display customer whose city is NOT 'Bangalore'.
run_sql("""SELECT * FROM customers
WHERE city NOT IN('Bangalore');""")
# Out:
#     customer_id first_name last_name              email       phone       city
# 0             3      Mohit     Kumar    mohit3@mail.com  9208428912     Mumbai
# 1             4     Simran       Das   simran4@mail.com  9979444461    Chennai
# 2             5       Yash    Sharma     yash5@mail.com  9426111115       Pune
# 3             6     Anjali     Singh   anjali6@mail.com  9693986973       Pune
# 4             7     Deepak    Wilson   deepak7@mail.com  9906274295  Hyderabad
# 5             8      Komal       Roy    komal8@mail.com  9467566361      Delhi
# 6             9      Nitin     Brown    nitin9@mail.com  9899533704  Hyderabad
# 7            10      Aisha     Kumar   aisha10@mail.com  9332083015    Chennai
# 8            12       Ritu     Kumar    ritu12@mail.com  9658448295      Delhi
# 9            13      Mohit       Das   mohit13@mail.com  9361812679  Hyderabad
# 10           14     Simran    Taylor  simran14@mail.com  9604314504    Kolkata
# ...

# %%
#3 Display products whose category is IN  and whose price is BETWEEN 1000 AND 5000.
run_sql("""SELECT * FROM products
WHERE category IN ('Electronic', 'Furniture')
AND price BETWEEN 1000 AND 50000;""")
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, price, stock_quantity]
# Index: []

# %%
#4 Display orders where customer_id is IN (2,3) OR employee_id is 1.
run_sql("""SELECT * FROM orders
WHERE customer_id IN (2,3)
OR product_id = 1;""")
# Out:
#     order_id  customer_id  product_id  order_date  quantity
# 0          7            2          20  2024-05-15         2
# 1         17           32           1  2024-05-30         4
# 2         23           11           1  2024-02-08         2
# 3         37            5           1  2025-12-31         4
# 4         52            2          23  2026-01-31         4
# 5         54           32           1  2025-11-11         2
# 6         58           30           1  2026-04-06         4
# 7         66            2           3  2024-08-03         4
# 8         69           34           1  2025-06-06         1
# 9         80            3           6  2024-01-26         2
# 10        84            3           4  2025-06-19         1
# 11        86           25           1  2024-07-25         4
# 12        89            3           1  2026-03-29         1

# %%
#5 Display employee _id, first_naem, and last_name for employees whose department_id is (1,2) and whose department_id is IN (1,2) and whose employee_id is NOT BETWEEN a AND 3.
run_sql("""SELECT employee_id, first_name, last_name
FROM employees
WHERE department_id IN (1,2)
AND employee_id NOT BETWEEN 1 AND 3;""")
# Out:
#    employee_id first_name last_name
# 0           11       Noah     Singh
# 1           12     Olivia       Roy
# 2           21      Arjun    Taylor
# 3           22       Isha       Roy

# %%
# Bonus Challenge
# Creat aquery that at least three filtering operator together to answer a bussiness-style question.
run_sql("""SELECT *
FROM Orders
WHERE customer_id IN (1,2,3)
AND order_id BETWEEN 5 AND 20
AND product_id <> 4;""")
# Out:
#    order_id  customer_id  product_id  order_date  quantity
# 0         7            2          20  2024-05-15         2
# 1        10            1          10  2024-07-16         5
