# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/100-days-sql/blob/main/day051sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('/content/company.db')

# Helper function to run SQL queries
def run_sql(query):
    return pd.read_sql_query(query, conn)

print("✅ Connected to company.db successfully!")
# Out:
# ✅ Connected to company.db successfully!

# %%
# Topic: LEFT JOIN - Introduction

# %%
#1
run_sql("""SELECT *
           FROM customers
           LEFT JOIN orders
           ON customers.customer_id = orders.customer_id;""")
# Out:
#      customer_id first_name last_name              email       phone  \
# 0              1      Akash    Sharma    akash1@mail.com  9666696518
# 1              2       Ritu       Das     ritu2@mail.com  9627404182
# 2              2       Ritu       Das     ritu2@mail.com  9627404182
# 3              2       Ritu       Das     ritu2@mail.com  9627404182
# 4              3      Mohit     Kumar    mohit3@mail.com  9208428912
# ..           ...        ...       ...                ...         ...
# 103           36     Anjali     Gupta  anjali36@mail.com  9310837702
# 104           37     Deepak    Wilson  deepak37@mail.com  9413891625
# 105           38      Komal       Roy   komal38@mail.com  9634822466
# 106           39      Nitin       Das   nitin39@mail.com  9759424149
# 107           40      Aisha    Taylor   aisha40@mail.com  9829603810
#
#           city  order_id  customer_id  product_id  order_date  quantity
# ...

# %%
#2
run_sql("""SELECT *
           FROM departments
           LEFT JOIN employees
           ON departments.department_id = employees.department_id;""")
# Out:
#     department_id   department_name  manager_id   location    budget  \
# 0               1                HR           1  Bangalore  300000.0
# 1               1                HR           1  Bangalore  300000.0
# 2               1                HR           1  Bangalore  300000.0
# 3               2           Finance           2     Mumbai  450000.0
# 4               2           Finance           2     Mumbai  450000.0
# 5               2           Finance           2     Mumbai  450000.0
# 6               3                IT           3  Bangalore  900000.0
# 7               3                IT           3  Bangalore  900000.0
# 8               3                IT           3  Bangalore  900000.0
# 9               4         Marketing           4      Delhi  350000.0
# 10              4         Marketing           4      Delhi  350000.0
# 11              4         Marketing           4      Delhi  350000.0
# 12              5             Sales           5  Hyderabad  700000.0
# ...

# %%
#3
# no supplier table

# %%
#4
run_sql("""SELECT *
        FROM products
        LEFT JOIN orders
        ON products.product_id = orders.product_id;""")
# Out:
#     product_id    product_name category    price  stock_quantity  order_id  \
# 0            1  Laptop Model 1   Laptop  90499.0              35        89
# 1            1  Laptop Model 1   Laptop  90499.0              35        37
# 2            1  Laptop Model 1   Laptop  90499.0              35        23
# 3            1  Laptop Model 1   Laptop  90499.0              35        86
# 4            1  Laptop Model 1   Laptop  90499.0              35        58
# ..         ...             ...      ...      ...             ...       ...
# 95          24   Mouse Model 4    Mouse   2999.0               0        85
# 96          24   Mouse Model 4    Mouse   2999.0               0        64
# 97          24   Mouse Model 4    Mouse   2999.0               0         3
# 98          25  Camera Model 1   Camera  46499.0               0        29
# 99          25  Camera Model 1   Camera  46499.0               0        65
#
#     customer_id  product_id  order_date  quantity
# ...

# %%
#5
run_sql("""SELECT
           customers.customer_id,
           customers.first_name,
           customers.last_name,
           COUNT(orders.order_id) AS total_orders
           FROM customers
           LEFT JOIN orders
           ON customers.customer_id = orders.customer_id
           GROUP BY
           customers.customer_id,
           customers.first_name,
           customers.last_name;""")
# Out:
#     customer_id first_name last_name  total_orders
# 0             1      Akash    Sharma             1
# 1             2       Ritu       Das             3
# 2             3      Mohit     Kumar             3
# 3             4     Simran       Das             3
# 4             5       Yash    Sharma             3
# 5             6     Anjali     Singh             0
# 6             7     Deepak    Wilson             1
# 7             8      Komal       Roy             3
# 8             9      Nitin     Brown             4
# 9            10      Aisha     Kumar             2
# 10           11      Akash     Patel             3
# 11           12       Ritu     Kumar             1
# 12           13      Mohit       Das             6
# 13           14     Simran    Taylor             5
# 14           15       Yash    Sharma             5
# 15           16     Anjali     Singh             5
# 16           17     Deepak    Taylor             2
# ...

# %%
# Bonucs Challege
run_sql("""SELECT
           departments.department_id,
           departments.department_name,
           AVG(employees.salary) AS average_salary
           FROM departments
           LEFT JOIN employees
           ON departments.department_id = employees.department_id
           GROUP BY
          departments.department_id,
          departments.department_name;""")
# Out:
#    department_id   department_name  average_salary
# 0              1                HR    67500.000000
# 1              2           Finance    71666.666667
# 2              3                IT    85000.000000
# 3              4         Marketing   109166.666667
# 4              5             Sales    83333.333333
# 5              6        Operations    98333.333333
# 6              7           Support    67500.000000
# 7              8             Legal    65000.000000
# 8              9  Data Engineering    59166.666667
# 9             10          Security   100833.333333
