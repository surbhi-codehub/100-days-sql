# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/100-days-sql/blob/main/day051python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Topic: Introduction to strings

# %%
#1
name = "Surbhi"

# %%
#2
colour = "Blue"

# %%
#3
name = "Surbhi"
color = "Blue"

print(name)
print(color)
# Out:
# Surbhi
# Blue

# %%
#4
name = "Surbhi"

name = "priya"

print(name)
# Out:
# priya

# %%
#5
name = "Surbhi"

print("My name is " + name)
# Out:
# My name is Surbhi

# %%
#6
name = "surbhi"
city = "Ranchi"
state ="Jharkhand"

print(name, colour, city)
# Out:
# surbhi Blue Ranchi

# %%
#7
for i in range(1, 6):
   for j in range(i):
       print("*", end="")
   print()
# Out:
# *
# **
# ***
# ****
# *****
