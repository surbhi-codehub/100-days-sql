# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhi-codehub/100-days-sql/blob/main/day033sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('/content/company.db')

# Helper function to run SQL queries
def run_sql(query):
    return pd.read_sql_query(query, conn)

print("✅ Connected to company.db successfully!")
# Out:
# ✅ Connected to company.db successfully!

# %%
# Topic: COUNT () with WHERE

# %%
#1 Count the total number of customers.
run_sql("""SELECT COUNT(*) AS total_customers
FROM customers;""")
# Out:
#    total_customers
# 0               40

# %%
#2 Count how many products belong to the Electrnics category.
run_sql("""SELECT COUNT(*) AS electronics_products
FROM products
WHERE category = 'Electronics';""")
# Out:
#    electronics_products
# 0                     0

# %%
#3 Count how many employees work in the Sales department using the department_id.
run_sql("""SELECT COUNT(*) AS sales_employees
FROM employees
WHERE department_id = (
   SELECT department_id
   FROM deapartments
   WHERE department_name = 'Sales'
   );""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: deapartments
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1512/1487465831.py in <cell line: 0>()
#       1 #3 Count how many employees work in the Sales department using the department_id.
# ----> 2 run_sql("""SELECT COUNT(*) AS sales_employees
#       3 FROM employees
#       4 WHERE department_id = (
#       5    SELECT department_id
#
# /tmp/ipykernel_1512/2685865391.py in run_sql(query)
#       7 # Helper function to run SQL queries
#       8 def run_sql(query):
# ...

# %%
#4 Count the number of orders placed where the quantity is greater than 3.
run_sql("""SELECT COUNT(*) AS orders_quantity_greater_than_3
FROM orders
WHERE quantity > 3;""")
# Out:
#    orders_quantity_greater_than_3
# 0                              39

# %%
#5 Count how many employees earn a salary greater than 60000.
run_sql("""SELECT COUNT(*) AS employees_salary_greater_than_60000
FROM employees
WHERE salary > 60000;""")
# Out:
#    employees_salary_greater_than_60000
# 0                                   19

# %%
# Bonus Challege
run_sql("""SELECT COUNT(*) AS matching_customers
FROM customers
WHERE city IN (
    SELECT city
    FROM employees
    );""")
# Out:
#    matching_customers
# 0                  40
